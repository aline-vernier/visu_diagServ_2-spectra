# %%
import zmq

# %%
context = zmq.Context()
socket = context.socket(zmq.REQ)
socket.connect("tcp://localhost:5555")
# Out:
# <SocketContext(connect='tcp://localhost:5555')>

# %%
# send message to get answer
socket.send_string("what is in the dict")

reply = socket.recv_string()
print("Server answer :", reply)
# Out:
# Réponse du serveur : {"state": "running", "shotNumber": 0, "data": 0.38143073311953324, "name": "spectrum"}
